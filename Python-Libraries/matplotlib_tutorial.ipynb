# %% [markdown]
# <a href="https://colab.research.google.com/github/Shamil2007/Python-Tutorials/blob/main/Python-Libraries/matplotlib_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #Linear Plot

# %%
# Median Developer Salaries by Age
ages_x = [18, 23, 27, 30, 33, 39, 42, 43, 45, 49, 55]

dev_y = [38496, 42000, 46752, 49320, 53200,
         56000, 62316, 64928, 67317, 68748, 73752]


plt.plot(ages_x, dev_y) # draws a line plot, connecting data points (ages_x vs dev_y).
plt.show() # displays the graph window.

# %% [markdown]
# ##Labels

# %%
plt.plot(ages_x, dev_y)
plt.xlabel("Ages") # adds a label to the x-axis
plt.ylabel("Median Salary (USD)") # adds a label to the y-axis
plt.title("Median Salary (USD) by Age") # adds a title above the graph

plt.show()

# %% [markdown]
# ##ADD Data

# %%
# Median Python Developer Salaries by Age
py_dev_y = [45372, 48876, 53850, 57287, 63016,
            65998, 70003, 70000, 71496, 75370, 83640]

plt.plot(ages_x, py_dev_y)

# Median Developers
plt.plot(ages_x, dev_y)

plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.title("Median Salary (USD) by Age")
plt.show()

# %% [markdown]
# Great, but we can not identify which python or median developer salary

# %% [markdown]
# ##Lengend

# %%
plt.plot(ages_x, py_dev_y, label="All Devs")

# Median Developers
plt.plot(ages_x, dev_y, label="Python Devs") # assigns a label to each line

plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.title("Median Salary (USD) by Age")

plt.legend() # shows a legend box to explain which line corresponds to which dataset

plt.show()

# %% [markdown]
# ##Line Styles

# %% [markdown]
# ![{40F05E11-5DBB-4225-BFF5-FEF0F6161665}.png](data:image/png;base64,...)

# %%
plt.plot(ages_x, py_dev_y, linestyle='--', label="All Devs")

# Median Developers
plt.plot(ages_x, dev_y, linestyle='-.', label="Python Devs")

plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.title("Median Salary (USD) by Age")

plt.legend()

plt.show()

# %% [markdown]
# ##Colors

# %%
plt.plot(ages_x, py_dev_y, linestyle='--', color="red", label="All Devs")

# Median Developers
plt.plot(ages_x, dev_y, linestyle='-.', color="green", label="Python Devs")

plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.title("Median Salary (USD) by Age")

plt.legend()

plt.show()

# %% [markdown]
# ##Marker

# %%
plt.plot(ages_x, py_dev_y, linestyle='--', color="red", marker='.', label="All Devs")

# Median Developers
plt.plot(ages_x, dev_y, linestyle='-.', color="green", marker='o', label="Python Devs")

plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.title("Median Salary (USD) by Age")

plt.legend()

plt.show()

# %% [markdown]
# ##Grid

# %%
plt.plot(ages_x, py_dev_y, linestyle='--', color="red", marker='.', label="All Devs")

# Median Developers
plt.plot(ages_x, dev_y, linestyle='-.', color="green", marker='o', label="Python Devs")

plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.title("Median Salary (USD) by Age")

plt.grid()
plt.legend()

plt.show()

# %% [markdown]
# ## Adding Padding

# %%
plt.plot(ages_x, py_dev_y, linestyle='--', color="red", marker='.', label="All Devs")

# Median Developers
plt.plot(ages_x, dev_y, linestyle='-.', color="green", marker='o', label="Python Devs")

plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.title("Median Salary (USD) by Age")

plt.grid()
plt.legend()

plt.tight_layout() # Automatically adjusts spacing so that labels, titles, and ticks don’t overlap
plt.show()

# %% [markdown]
# ##Plt Styles

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('Solarize_Light2')

plt.plot(ages_x, py_dev_y, linestyle='--', color="red", marker='.', label="All Devs")

# Median Developers
plt.plot(ages_x, dev_y, linestyle='-.', color="green", marker='o', label="Python Devs")

plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.title("Median Salary (USD) by Age")

plt.grid()
plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.style.use('fivethirtyeight')

plt.plot(ages_x, py_dev_y, linestyle='--', color="red", marker='.', label="All Devs")

# Median Developers
plt.plot(ages_x, dev_y, linestyle='-.', color="green", marker='o', label="Python Devs")

plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.title("Median Salary (USD) by Age")

plt.grid()
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Save Plot

# %%
plt.style.use("seaborn-v0_8-darkgrid")

plt.plot(ages_x, py_dev_y, linestyle='--', color="red", marker='.', label="All Devs")

# Median Developers
plt.plot(ages_x, dev_y, linestyle='-.', color="green", marker='o', label="Python Devs")

plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.title("Median Salary (USD) by Age")

plt.grid()
plt.legend()

plt.tight_layout()

plt.savefig('developer_salaries.png') # For saving
plt.show()

# %% [markdown]
# # Pie Charts

# %%
slices = [30, 70]

plt.pie(slices) # draws a pie chart.

plt.title("Pie chart Intro")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##Label

# %%
labels = ["Developers", "Others"]
slices = [30, 70] # Each value in slices represents a portion of the circle.

plt.pie(slices, labels=labels) # assigns category names to each slice.

plt.title("Pie chart Intro")
plt.tight_layout()
plt.show()

# %%
labels = ["Developers", "Others"]

#The numbers sum sholdn't be always equal to 100
slices = [30, 50]

plt.pie(slices, labels=labels)

plt.title("Pie chart Intro")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Wedge color and size

# %%
labels = ["Developers", "Others"]
slices = [30, 70]

plt.pie(slices, labels=labels, wedgeprops={'edgecolor': 'Green', 'linewidth': 2})
# edgecolor -> controls the appearance of pie slices
# edgecolor='Green' → sets border color of slices.
# linewidth=3 → makes borders thicker.

plt.title("Pie chart Intro")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## More slices

# %%
labels = ["Developers", "Marketings", "Accountants", "Salers"]
slices = [30, 20, 10, 50]

plt.pie(slices, labels=labels, wedgeprops={'edgecolor': 'Black', 'linewidth': 2})

plt.title("Pie chart Intro")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##Colors

# %%
colors = ['r', 'b', 'y', 'lightblue']

plt.pie(slices, labels=labels, wedgeprops={'edgecolor': 'Black', 'linewidth': 2}, colors=colors)

plt.title("Pie chart Intro")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##Explode

# %%
labels = ["Developers", "Marketings", "Accountants", "Salers"]
explodes = [0, 0, 0.1, 0] # separates slices from the pie

plt.pie(slices, labels=labels, explode=explodes,
        wedgeprops={'edgecolor': 'black', 'linewidth': 1.5})

plt.title("Pie chart Intro")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##Percentage

# %%
plt.pie(slices, labels=labels,
        autopct='%1.2f%%',
        wedgeprops={'edgecolor': 'black', 'linewidth': 1.5})

# autopct='%1.2f%%' → shows percentage values on slices.

# %1.2f%% → display with 2 decimal places (e.g., 25.00%).

# %1.0f%% → no decimals (e.g., 25%).

plt.title("Pie chart Intro")
plt.tight_layout()
plt.show()

# %% [markdown]
# #Histograms

# %%
ages = [18, 19, 21, 25, 26, 26, 30, 32, 38, 45, 55]

plt.hist(ages)

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

plt.tight_layout()

plt.show()

# %% [markdown]
# ##Bins

# %%
ages = [18, 19, 21, 25, 26, 26, 30, 32, 38, 45, 55]

plt.hist(ages, bins=20)
# bins=20 → splits the data into 20 intervals.

# More bins → more detailed view.

# Fewer bins → more general view

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

plt.tight_layout()

plt.show()

# %%
ages = [18, 19, 21, 25, 26, 26, 30, 32, 38, 45, 55]
bins = [10, 20, 30, 40, 50]

plt.hist(ages, bins=bins, edgecolor='black')

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

plt.tight_layout()

plt.show()

# %% [markdown]
# ##Edge color

# %%
ages = [18, 19, 21, 25, 26, 26, 30, 32, 38, 45, 55]

plt.hist(ages, bins=20, edgecolor='black')

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

plt.tight_layout()

plt.show()

# %%
df = pd.read_csv("data.csv")

ages = df["Age"]

plt.hist(ages, bins=20, edgecolor='black')

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Logarithmic scale

# %%
df = pd.read_csv("data.csv")

ages = df["Age"]

plt.hist(ages, bins=20, edgecolor='black', log=True)
# edgecolor='black' → adds borders to bars for clarity.

# log=True → y-axis uses logarithmic scale instead of linear.

# Useful when values vary widely (to avoid tall bars hiding small ones

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

plt.tight_layout()

plt.show()

# %% [markdown]
# ##Vertical Line

# %%
df = pd.read_csv("data.csv")

ages = df["Age"]

plt.hist(ages, bins=20, edgecolor='black', log=True)

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

median_age = ages.median()

plt.axvline(median_age, color="black")
# plt.axvline() → draws a vertical reference line.

# Here, it marks the median age.
# color="black" → sets the line color.

plt.tight_layout()

plt.show()

# %% [markdown]
# #SubPlots

# %%
plt.subplot(2, 2, 1)  # (rows, cols, position)
plt.plot([1, 2, 3], [1, 4, 9], 'r')   # First subplot

plt.subplot(2, 2, 2)
plt.plot([1, 2, 3], [1, 2, 3], 'g')   # Second subplot

plt.subplot(2, 2, 3)
plt.plot([1, 2, 3], [1, 8, 27], 'b')  # Third subplot

plt.subplot(2, 2, 4)
plt.plot([1, 2, 3], [3, 2, 1], 'k')   # Fourth subplot

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(2, 2)  # 2x2 grid

ax[0, 0].plot([1, 2, 3], [1, 4, 9], 'r')
ax[0, 1].plot([1, 2, 3], [1, 2, 3], 'g')
ax[1, 0].plot([1, 2, 3], [1, 8, 27], 'b')
ax[1, 1].plot([1, 2, 3], [3, 2, 1], 'k')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(2, 2, sharex=True, sharey=True)

# sharex=True → all subplots share the same x-axis.

# sharey=True → all subplots share the same y-axis.

ax[0, 0].hist([1, 2, 2, 3])
ax[0, 1].hist([2, 3, 3, 4])
ax[1, 0].hist([3, 4, 4, 5])
ax[1, 1].hist([4, 5, 5, 6])

plt.show()
